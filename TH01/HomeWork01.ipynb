# %% [markdown]
# ### Bai 1: Nhap vao một số nguyên, in ra màn hình giá trị gấp đôi của nó

# %%
def num(a):
    print(a*2)

num(2)
# Out:
# 4

# %% [markdown]
# ### Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ta xây một khu vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2 chữ số phần thập phân.

# %%
def canh(a,b):
    Shcn = float(a*b)
    Sht = float(3.14 * (a/2)**2)
    Sco = Shcn - Sht
    print(f'{Sco:.2f}')

canh(1,2)
# Out:
# 1.21

# %% [markdown]
# ### Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if....else, ma)

# %%
def cha(a):
    if 'A' <= a <= 'Z':
        print(a.lower())
    elif 'a' <= a <= 'z':
        print(a.upper())
    
cha('D')
# Out:
# d

# %% [markdown]
# ### Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
def cha(a):
    if a == 'A':
        print('z')
    else:
        print(chr(ord(a)-1).lower())
    
cha('A')
# Out:
# z

# %% [markdown]
# ### Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không, nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
def tamgiac(a,b,c):
    if (a+b>c) and (a+c>b) and (b+c>a):
        p = float((a+b+c)/2)
        heron = float((p * (p-a) * (p-b) * (p-c))**0.5)
        print(f'{heron:.1f}')
    else:
        print('Khong phai 3 canh cua tam giac')
    
tamgiac(3,4,5)
# Out:
# 6.0

# %% [markdown]
# ### Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và thứ chín của chuỗi này.

# %%
def cha(a):
    if len(a) >= 20:
        print(a[4])
        print(a[8])

cha('qwertyuiopasdfghjklzxcvbnm')
# Out:
# t
# o

# %% [markdown]
# ### Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này, tính tiền điện tháng này cho hộ biết:
# ### Từ 0 – 50kWh: 1.984 đồng/kWh
# ### Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# ### Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# ### Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# ### Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# ### Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# ### Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng.

# %%
name = input('Ten chu ho: ')
cu = int(input('Chi so thang truoc: '))
moi = int(input('Chi so thang nay: '))
tieuthu = moi - cu
#VAT = float(truocthue * 0.08)
#tongtien = truocthue + VAT chi lay 3 chu so sau dau phay
if tieuthu <= 50: #BAC1
    truocthue = float(tieuthu * 1.984)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT
elif 50 < tieuthu <= 100: #BAC2
    truocthue = float((tieuthu - 50) * 2.050 + 99.2)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT

elif 100 < tieuthu <= 200: #BAC3
    truocthue = float((tieuthu - 100) * 2.380 + 99.2 + 102.5)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT

elif 200 < tieuthu <= 300: #BAC4
    truocthue = float((tieuthu - 200) * 2.998 + 99.2 + 102.5 + 238.0)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT

elif 300 < tieuthu <= 400: #BAC5
    truocthue = float((tieuthu - 300) * 3.350 + 99.2 + 102.5 + 238.0 + 299.8)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT

else: #BAc6
    truocthue = float((tieuthu - 400) * 3.460 + 99.2 + 102.5 + 238.0 + 299.8 + 335.0)
    VAT = float(truocthue * 0.08)
    tongtien = truocthue + VAT


print(f'Ho va ten: {name}')
print(f'Tien phai tra la: {tongtien:.3f}')
# Out:
# Ho va ten: Nguyen Xuan Hai
# Tien phai tra la: 1855.505

# %% [markdown]
# ### Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó là số chẵn hay số lẻ.

# %%
def num(a):
    if a % 2 == 0:
        print('Even')
    else:
        print('Odd')

num(3)
# Out:
# Odd

# %% [markdown]
# ### Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra "True", nếu sai in ra "False".

# %%
def num(n):
    if n % 5 == 0 and n % 10 != 0:
        return True
    else:
        return False
    
num(0)
# Out:
# False

# %% [markdown]
# ### Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra "True", nếu sai in ra "False".

# %%
def num(n):
    if n % 3 == 0 and n % 5 == 0:
        return True
    else:
        return False
    
num(15)
# Out:
# True

# %% [markdown]
# ### Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
def year(n):
    age =  2026 - n
    if age >= 18:
        return True
    else:
        return False

year(2007)
# Out:
# True

# %% [markdown]
# ### So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo nếu hai số bằng nhau.

# %%
def num(a,b):
    if a>b:
        print(a)
    elif b>a:
        print(b)
    elif a == b:
        print('Equals')

num(5,5)
# Out:
# Equals

# %% [markdown]
# ### .Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm tra xem ký tự đó là chữ cái hay số

# %%
def nhap(n):
    if ('A' <= n <= 'Z') or ('a' <= n <= 'z'):
        print('Chu')
    elif '0' <= n <= '9':
        print('So')

nhap('0')
# Out:
# So

# %% [markdown]
# ### Tính điểm học lực: Nhập điểm (0-10), phân loại học lực theo quy tắc: >= 8: Giỏi >= 6.5 và < 8: Khá >= 5 và < 6.5: Trung bình < 5: Yếu

# %%
def score(n):
    if n >= 8:
        print('Gioi')
    elif 6.5 <= n < 8:
        print('Kha')
    elif 5 <= n < 6.5:
        print('Trung binh')
    else:
        print('Yeu')
    
score(8)
# Out:
# Yeu

# %% [markdown]
# ### Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4 nhưng không chia hết cho 100).

# %%
def year(n):
    if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
        print('Nhuan')
    else:
        print('Khong nhuan')

year(2002)
# Out:
# Khong nhuan

# %% [markdown]
# ### Chuyển đổi số thành chữ số: Nhập một số nguyên từ 0 đến 9, in ra tên chữ số tương ứng (0 -> "Không", 1 -> "Một", ...) – Xem trước match ... case.

# %%
def check(n):
    match n:
        case 0:
            print('Khong')
        case 1:
            print('Mot')
        case 2:
            print('Hai')
        case 3:
            print('Ba')
        case 4:
            print('Bon')
        case 5:
            print('Nam')
        case 6:
            print('Sau')
        case 7:
            print('Bay')
        case 8:
            print('Tam')
        case 9:
            print('Chin')

check(5)
# Out:
# Nam

# %% [markdown]
# ### Kiểm tra điểm thi xem có qua môn hay phải học lại: Nhập điểm thi, nếu điểm >= 4 thì in "Qua môn", ngược lại in "Học lại".

# %%
def score(n):
    if n >= 4:
        print('Qua môn')
    else:
        print('Học lại')

score(4)
# Out:
# Qua môn

# %% [markdown]
# ### Kiểm tra năm sinh và tính tuổi: Nhập năm sinh, tính tuổi hiện tại (giả sử năm hiện tại là 2025), và kiểm tra xem người đó có đủ 18 tuổi hay chưa.

# %%
def age(n):
    age = 2025 - n
    if age >= 18:
        print('Da du 18 tuoi')
    else:
        print('Chua du 18 tuoi')

age(2007)
# Out:
# Da du 18 tuoi
