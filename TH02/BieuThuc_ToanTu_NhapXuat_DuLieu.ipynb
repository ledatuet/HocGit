# %% [markdown]
# ### W2A1

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# ### W2A2

# %%
name = input()
print(f'Xin chao {name}')
# Out:
# Xin chao Dat

# %% [markdown]
# ### W2A3

# %%
def num(a,b):
    print(a+b)
    print(a-b)
    print(a*b)
    print(a//b)
    print(a%b)
    print(f'{float(a/b):.2f}')

num(3,2)
# Out:
# 5
# 1
# 6
# 1
# 1
# 1.50

# %% [markdown]
# ### W2A4

# %%
a1, b1, c1, a2, b2, a3 = map(int,input().split())
tb = float(((a1+b1+c1) + (a2+b2)*2 + a3*3)/10)
print(f'{tb:.1f}')
# Out:
# 4.2

# %% [markdown]
# ### W2A5

# %%
def num(a,b):
    print(int(a**b))

num(2,3)
# Out:
# 8

# %% [markdown]
# ### W2A6

# %%
def cha(a):
    print(ord(a))
    print(a.upper())

cha('a')
# Out:
# 97
# A

# %% [markdown]
# ### W2A7

# %%
print(((13**2)*3)+5)
print(13**2*3 + 5)
# Out:
# 512
# 512

# %% [markdown]
# ### W2A8

# %%
def nhietdo(c):
    print(f'{float((9/5)*c+32):.2f}')

nhietdo(0)
# Out:
# 32.00

# %% [markdown]
# ### W2A9

# %%
def USD(x):
    print(f'{float(x + (x*0.3) + x*(0.1) + 10):.2f}')

USD(2)
# Out:
# 12.80

# %% [markdown]
# ### W2A10

# %%
name1, name2, name3 = list(input().split())

print(f'Hi {name3}, {name2} and {name1}.')
# Out:
# Hi Helen, Alice and Bob.

# %% [markdown]
# ### W2A11

# %%
def giay(gio,phut):
    print(gio*3600 + phut*60)

giay(1,0)
# Out:
# 3600

# %% [markdown]
# ### W2A12

# %%
def canh(a):
    print(a*a*6)

canh(5)
# Out:
# 150

# %% [markdown]
# ### W2A13

# %%
def so(a,b):
    tich = (a*b)%10
    print(tich)

so(5,8)
# Out:
# 0

# %% [markdown]
# ### W2A14

# %%
def nhap(a,b):
    print(f'{b}, {a}')

nhap(1,2)
# Out:
# 2, 1

# %% [markdown]
# ### W2A15

# %%
n = int(input())
print('*' * n)
# Out:
# ****

# %% [markdown]
# ### W2A16

# %%
print('Spring \nSummer \nAutumn \nWinter')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# ### W2A17

# %%
n = int(input())
for i in range(1,n+1):
    print('*' * i)
# Out:
# *
# **
# ***

# %% [markdown]
# ### W2A18

# %%
print('### ##  ### ###')
print(' #  # #  #   # ')
print(' #  # #  #   # ')
print(' #  # #  #   # ')
print(' #  ##   #   # ')
# Out:
# ### ##  ### ###
#  #  # #  #   #
#  #  # #  #   #
#  #  # #  #   #
#  #  ##   #   #

# %% [markdown]
# ### W2A19

# %%
print('Monday')
print('Tuesday')
print('Wednesday')
print('Thursday')
print('Friday')
print('Saturday')
print('Sunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# ### W2A20

# %%
print('January')
print('February')
print('March')
print('April')
print('May')
print('June')
print('July')
print('August')
print('September')
print('October')
print('November')
print('December')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# ### W2A21

# %%
print('Hello, world\n'*10)
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
